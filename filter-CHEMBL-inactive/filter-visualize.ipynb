# %%
import pandas as pd

df = pd.read_csv("CHEMBL-Pt.csv")
display(df)
# Out:
#    Molecule ChEMBL ID                                      Molecule Name  \
# 0       CHEMBL1743594        Cis-[Pt(1,3-diaminepropane)2(O-Glutarate)2]
# 1       CHEMBL1743593  Cis-[Pt(1,3-diaminepropane)2] 1,1-cyclobutaned...
# 2       CHEMBL1743583  Cis-[Pt(1,3-diaminebutane)2(OH)2] 1,1-cyclobut...
# 3         CHEMBL19739                       [{cis-Pt(NH3)2Cl}2(-pzn)]Cl2
# 4       CHEMBL1794811          Cis-[Pt(1,3-diaminepropane)2(O-Maleate)2]
# 5       CHEMBL2068258  Cis-[Pt(1,3-diaminebutane) 1,1-cyclobutanedica...
# 6       CHEMBL1743591         Cis-[Pt(1,3-diaminebutane)2(O-Succinate)2]
# 7       CHEMBL2068442  Cis-[Pt(1,3-diaminepropane) 1,1-cyclobutanedic...
# 8       CHEMBL1743584        Cis-[Pt(1,3-diaminepropane)2(O-Succinate)2]
# 9        CHEMBL343632                                      [Pt(en)BPMAA]
# 10      CHEMBL1743586  Cis-[Pt(1,3-diaminepropane)2(OH)2] 1,1-cyclobu...
# 11      CHEMBL1743600  Cis-[Pt(1,3-diaminebutane)2] 1,1-cyclobutanedi...
# ...

# %%
df1 = pd.read_csv("CHEMBL-platinum.csv")
display(df1)
# Out:
#    Molecule ChEMBL ID                                      Molecule Name  \
# 0        CHEMBL361029             camphorato platinum complex derivative
# 1        CHEMBL286548                                   Platinum complex
# 2       CHEMBL2068304            triphenylethylene platinum (II) complex
# 3        CHEMBL441330     (2,2':6',2''-terpyridine)platinum (II) complex
# 4        CHEMBL103847   Trans-Amminedichloro(diethylamine)platinium (II)
# 5         CHEMBL34295                                   Platinum complex
# 6        CHEMBL285449                                   Platinum complex
# 7          CHEMBL6513                                   Platinum complex
# 8        CHEMBL415294     (2,2':6',2''-terpyridine)platinum (II) complex
# 9        CHEMBL191157             camphorato platinum complex derivative
# 10      CHEMBL2068257                                   platinum complex
# 11      CHEMBL2068529                                   platinum complex
# ...
